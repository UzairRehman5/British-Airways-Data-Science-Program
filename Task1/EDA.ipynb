# %%
# Importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing dataset
df = pd.read_csv("df.csv")
df.sample(5)
# Out:
#            Aircraft Type Of Traveller       Seat Type                Route  \
# 1622           A319          Business   Economy Class                Other
# 870           Other      Solo Leisure   Economy Class                Other
# 1696  Not available    Family Leisure   Economy Class                Other
# 660           Other      Solo Leisure  Business Class                Other
# 3099  Not available    Family Leisure  Business Class  Vancouver to London
#
#           Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 1622      March 2017             2                    5                 3
# 870            Other             1                    4                 3
# 1696   February 2017             1                    1                 1
# 660   September 2019             1                    2                 2
# 3099           Other             2                    1                 1
#
# ...

# %% [markdown]
# # EDA on 'Aircraft' column

# %%
sns.clustermap(pd.crosstab(df['Aircraft'],df['Recommended']), cmap='coolwarm', figsize=(10, 8))

# %%
plt.figure(figsize=(20, 6))

# Create the strip plot using Seaborn
sns.stripplot(x='Aircraft', y='Type Of Traveller', data=df, hue='Recommended', dodge=True)
# Out:
# <AxesSubplot:xlabel='Aircraft', ylabel='Type Of Traveller'>

# %%
plt.figure(figsize=(20, 6))

# Create the strip plot using Seaborn
sns.stripplot(x='Aircraft', y='Seat Type', data=df, hue='Recommended', dodge=True)
# Out:
# <AxesSubplot:xlabel='Aircraft', ylabel='Seat Type'>

# %% [markdown]
# # EDA on 'Type of Traveller' column

# %%
sns.heatmap(pd.crosstab(df['Type Of Traveller'],df['Recommended']))
# Out:
# <AxesSubplot:xlabel='Recommended', ylabel='Type Of Traveller'>

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(x='Type Of Traveller',y='Seat Type', data=df, hue='Recommended', dodge=True)
# Out:
# <AxesSubplot:xlabel='Type Of Traveller', ylabel='Seat Type'>

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(x='Type Of Traveller',y='Value For Money', data=df, hue='Recommended', dodge=True)
# Out:
# <AxesSubplot:xlabel='Type Of Traveller', ylabel='Value For Money'>

# %% [markdown]
# # EDA on 'Seat Type' column

# %%
sns.heatmap(pd.crosstab(df['Seat Type'],df['Recommended']))
# Out:
# <AxesSubplot:xlabel='Recommended', ylabel='Seat Type'>

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(x='Seat Type',y='Value For Money', data=df, hue='Recommended', dodge=True)
# Out:
# <AxesSubplot:xlabel='Seat Type', ylabel='Value For Money'>

# %% [markdown]
# # EDA on 'Route' column

# %%
filtered_df = df[df['Route'] != 'Other']

# Create a crosstab to prepare the data for clustering
crosstab = pd.crosstab(filtered_df['Route'], df['Recommended'])

# Create a clustermap using Seaborn
sns.clustermap(crosstab, cmap='coolwarm', figsize=(10, 8))

# %% [markdown]
# # EDA on 'Date Flown' column

# %%
filtered_df = df[df['Date Flown'] != 'Other']

# Create a crosstab to prepare the data for clustering
crosstab = pd.crosstab(filtered_df['Date Flown'], df['Recommended'])

# Create a clustermap using Seaborn
sns.clustermap(crosstab, cmap='coolwarm', figsize=(10, 8))

# %% [markdown]
# # EDA on 'Seat Comfort' column

# %%
sns.heatmap(pd.crosstab(df['Seat Comfort'],df['Recommended']))
# Out:
# <AxesSubplot:xlabel='Recommended', ylabel='Seat Comfort'>

# %%
plt.figure(figsize=(20, 6))

# Create the strip plot using Seaborn
sns.stripplot(x='Aircraft', y='Seat Comfort', data=df, hue='Recommended', dodge=True)
# Out:
# <AxesSubplot:xlabel='Aircraft', ylabel='Seat Comfort'>

# %% [markdown]
# # EDA on 'Cabin Staff Service'

# %%
sns.heatmap(pd.crosstab(df['Cabin Staff Service'], df['Recommended']))
# Out:
# <AxesSubplot:xlabel='Recommended', ylabel='Cabin Staff Service'>

# %%
plt.figure(figsize=(20, 6))

# Create the strip plot using Seaborn
sns.stripplot(x='Aircraft', y='Cabin Staff Service', data=df, hue='Recommended', dodge=True)
# Out:
# <AxesSubplot:xlabel='Aircraft', ylabel='Cabin Staff Service'>

# %% [markdown]
# # EDA on 'Food & Beverages' column

# %%
sns.heatmap(pd.crosstab(df['Food & Beverages'], df['Recommended']))
# Out:
# <AxesSubplot:xlabel='Recommended', ylabel='Food & Beverages'>

# %%
plt.figure(figsize=(20, 6))

# Create the strip plot using Seaborn
sns.stripplot(x='Aircraft', y='Food & Beverages', data=df, hue='Recommended', dodge=True)
# Out:
# <AxesSubplot:xlabel='Aircraft', ylabel='Food & Beverages'>

# %% [markdown]
# # EDA on 'Inflight Entertainment' column

# %%
sns.heatmap(pd.crosstab(df['Inflight Entertainment'], df['Recommended']))
# Out:
# <AxesSubplot:xlabel='Recommended', ylabel='Inflight Entertainment'>

# %%
plt.figure(figsize=(20, 6))

# Create the strip plot using Seaborn
sns.stripplot(x='Aircraft', y='Inflight Entertainment', data=df, hue='Recommended', dodge=True)
# Out:
# <AxesSubplot:xlabel='Aircraft', ylabel='Inflight Entertainment'>

# %% [markdown]
# # EDA on 'Ground Service' column

# %%
sns.heatmap(pd.crosstab(df['Ground Service'], df['Recommended']))
# Out:
# <AxesSubplot:xlabel='Recommended', ylabel='Ground Service'>

# %%
plt.figure(figsize=(20, 6))

# Create the strip plot using Seaborn
sns.stripplot(x='Aircraft', y='Ground Service', data=df, hue='Recommended', dodge=True)
# Out:
# <AxesSubplot:xlabel='Aircraft', ylabel='Ground Service'>

# %% [markdown]
# # EDA on 'Value For Money' column

# %%
sns.heatmap(pd.crosstab(df['Value For Money'], df['Recommended']))
# Out:
# <AxesSubplot:xlabel='Recommended', ylabel='Value For Money'>

# %%
plt.figure(figsize=(20, 6))

# Create the strip plot using Seaborn
sns.stripplot(x='Aircraft', y='Value For Money', data=df, hue='Recommended', dodge=True)
# Out:
# <AxesSubplot:xlabel='Aircraft', ylabel='Value For Money'>

# %% [markdown]
# # EDA on 'Recommended' column

# %%
# Plot a bar chart to visualize the value counts of the 'Value For Money' column in the DataFrame 'df'.
df['Recommended'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation Heatmap of Multivariate Relationships

# %%
# Define the subset of columns for correlation analysis
subset_columns = ['Seat Comfort','Cabin Staff Service','Food & Beverages','Inflight Entertainment','Ground Service','Value For Money','Recommended']

# Calculate the correlation matrix for the selected columns
corr_matrix = df[subset_columns].corr()

# Create a figure with a specified size
plt.figure(figsize=(10, 8))

# Create a heatmap to visualize the correlation matrix, with annotations and a Blue color map
sns.heatmap(corr_matrix, annot=True, cmap='Blues')

# Set the title of the plot
plt.title('Correlation Heatmap of Multivariate Relationships')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Multivariate Relationships')
